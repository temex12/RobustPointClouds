# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {
    'Metric': ['bbox', 'bev', '3d', 'aos'],
    'Easy Baseline': [95.171, 89.9659, 88.3587, 94.91],
    'Easy Adversarial': [90.3787, 89.3457, 77.0286, 90.19],
    # Add 'Medium Baseline', 'Medium Adversarial', 'Hard Baseline', 'Hard Adversarial'
}

df = pd.DataFrame(data)

# Plotting
ax = df.plot(kind='bar', x='Metric', figsize=(10, 8))
ax.set_ylabel('AP11 Score')
ax.set_title('Comparison of Model Performances for AP11 with IoU 0.70')
plt.tight_layout()
plt.show()
